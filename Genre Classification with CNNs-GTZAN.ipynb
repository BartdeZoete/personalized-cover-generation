# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# In /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
from fastai.vision import *
from fastai.metrics import error_rate,Precision,Recall
import disarray

# %%
import torch
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="4,5,6,7"

# %%
bs = 32
path = Path('/data/s2965003/gtzan_data/images_original')
data = ImageDataBunch.from_folder(path, train="/data/s2965003/gtzan_data/images_original", valid_pct=0.2, size=256, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['blues',
#  'classical',
#  'country',
#  'disco',
#  'hiphop',
#  'jazz',
#  'metal',
#  'pop',
#  'reggae',
#  'rock']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %% [markdown]
# ## With ResNet34

# %%
learn = create_cnn(data, models.resnet34, metrics=[error_rate,Precision(),Recall()])
#learn.model = torch.nn.DataParallel(learn.model, device_ids=[4,5])
#learn.model.to(f'cuda:{learn.model.device_ids[0]}')
# Out:
# /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/fastai/vision/learner.py:109: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")

# %%
??create_cnn

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.278717</td>
#       <td>1.830365</td>
#       <td>0.613065</td>
#       <td>nan</td>
#       <td>0.363543</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.288183</td>
#       <td>1.320433</td>
#       <td>0.427136</td>
#       <td>0.580183</td>
#       <td>0.561588</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.639152</td>
#       <td>1.268495</td>
#       <td>0.351759</td>
#       <td>0.637382</td>
#       <td>0.641270</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.225824</td>
#       <td>1.254663</td>
#       <td>0.336683</td>
#       <td>0.659504</td>
#       <td>0.664082</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.952921</td>
#       <td>1.243187</td>
#       <td>0.341709</td>
#       <td>0.656952</td>
#       <td>0.658200</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>
# /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/fastai/metrics.py:191: UserWarning: average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.
#   warn("average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.")

# %%
#learn.lr_find()
#learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(25, max_lr=slice(1e-4,1e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.516422</td>
#       <td>1.312620</td>
#       <td>0.346734</td>
#       <td>0.634134</td>
#       <td>0.657499</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.450370</td>
#       <td>1.240712</td>
#       <td>0.366834</td>
#       <td>0.636336</td>
#       <td>0.619428</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.462653</td>
#       <td>2.632174</td>
#       <td>0.417085</td>
#       <td>0.558783</td>
#       <td>0.598678</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.589261</td>
#       <td>2.915261</td>
#       <td>0.462312</td>
#       <td>0.483853</td>
#       <td>0.510802</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.713787</td>
#       <td>3.540086</td>
#       <td>0.502513</td>
#       <td>0.514076</td>
#       <td>0.496287</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.676900</td>
#       <td>2.472847</td>
#       <td>0.356784</td>
#       <td>0.726550</td>
#       <td>0.610015</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.576345</td>
#       <td>2.606710</td>
#       <td>0.386935</td>
#       <td>0.631934</td>
#       <td>0.609911</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.486309</td>
#       <td>1.801821</td>
#       <td>0.346734</td>
#       <td>0.685670</td>
#       <td>0.641754</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.433469</td>
#       <td>4.204397</td>
#       <td>0.567839</td>
#       <td>0.679937</td>
#       <td>0.453125</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.380335</td>
#       <td>2.529965</td>
#       <td>0.417085</td>
#       <td>0.709481</td>
#       <td>0.597042</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.323355</td>
#       <td>1.642932</td>
#       <td>0.311558</td>
#       <td>0.701972</td>
#       <td>0.683289</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.283019</td>
#       <td>1.769146</td>
#       <td>0.291457</td>
#       <td>0.716832</td>
#       <td>0.716720</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.231242</td>
#       <td>1.761265</td>
#       <td>0.341709</td>
#       <td>0.661415</td>
#       <td>0.660711</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.191305</td>
#       <td>1.525759</td>
#       <td>0.291457</td>
#       <td>0.711948</td>
#       <td>0.702577</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.150391</td>
#       <td>1.638636</td>
#       <td>0.301508</td>
#       <td>0.725208</td>
#       <td>0.690708</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.119411</td>
#       <td>1.592259</td>
#       <td>0.311558</td>
#       <td>0.720262</td>
#       <td>0.685675</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.095507</td>
#       <td>1.567456</td>
#       <td>0.291457</td>
#       <td>0.744104</td>
#       <td>0.707344</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.078039</td>
#       <td>1.528946</td>
#       <td>0.281407</td>
#       <td>0.746358</td>
#       <td>0.716868</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.062827</td>
#       <td>1.511748</td>
#       <td>0.281407</td>
#       <td>0.751532</td>
#       <td>0.717988</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.049646</td>
#       <td>1.502658</td>
#       <td>0.276382</td>
#       <td>0.752668</td>
#       <td>0.722750</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
cm=interp.confusion_matrix()
df = pd.DataFrame(cm)
df.da.export_metrics()
# Out:
#                                   0         1         2         3         4  \
# accuracy                   0.964824  0.984925  0.924623  0.919598  0.949749
# f1                         0.820513  0.943396  0.666667  0.636364  0.666667
# false_discovery_rate       0.200000  0.038462  0.250000  0.222222  0.375000
# false_negative_rate        0.157895  0.074074  0.400000  0.461538  0.285714
# false_positive_rate        0.022222  0.005814  0.028736  0.023121  0.032432
# negative_predictive_value  0.983240  0.988439  0.944134  0.933702  0.978142
# positive_predictive_value  0.800000  0.961538  0.750000  0.777778  0.625000
# precision                  0.800000  0.961538  0.750000  0.777778  0.625000
# recall                     0.842105  0.925926  0.600000  0.538462  0.714286
# sensitivity                0.842105  0.925926  0.600000  0.538462  0.714286
# specificity                0.977778  0.994186  0.971264  0.976879  0.967568
# true_negative_rate         0.977778  0.994186  0.971264  0.976879  0.967568
# true_positive_rate         0.842105  0.925926  0.600000  0.538462  0.714286
#
#                                   5         6         7         8         9  \
# accuracy                   0.964824  0.984925  0.969849  0.934673  0.849246
# f1                         0.774194  0.926829  0.800000  0.606061  0.423077
# false_discovery_rate       0.076923  0.050000  0.200000  0.375000  0.685714
# false_negative_rate        0.333333  0.095238  0.200000  0.411765  0.352941
# false_positive_rate        0.005525  0.005618  0.016304  0.032967  0.131868
# negative_predictive_value  0.967742  0.988827  0.983696  0.961749  0.963415
# positive_predictive_value  0.923077  0.950000  0.800000  0.625000  0.314286
# precision                  0.923077  0.950000  0.800000  0.625000  0.314286
# recall                     0.666667  0.904762  0.800000  0.588235  0.647059
# sensitivity                0.666667  0.904762  0.800000  0.588235  0.647059
# specificity                0.994475  0.994382  0.983696  0.967033  0.868132
# true_negative_rate         0.994475  0.994382  0.983696  0.967033  0.868132
# true_positive_rate         0.666667  0.904762  0.800000  0.588235  0.647059
#
#                            micro-average
# accuracy                        0.944724
# f1                              0.723618
# false_discovery_rate            0.276382
# false_negative_rate             0.276382
# false_positive_rate             0.030709
# negative_predictive_value       0.969291
# positive_predictive_value       0.723618
# precision                       0.723618
# recall                          0.723618
# sensitivity                     0.723618
# specificity                     0.969291
# true_negative_rate              0.969291
# true_positive_rate              0.723618

# %% [markdown]
# ## With ResNet50

# %%
learn=None
torch.cuda.empty_cache()
learn = create_cnn(data, models.resnet50, metrics=[error_rate,Precision(),Recall()])
# Out:
# /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/fastai/vision/learner.py:109: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.661399</td>
#       <td>2.387275</td>
#       <td>0.597990</td>
#       <td>nan</td>
#       <td>0.405913</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.677022</td>
#       <td>1.450851</td>
#       <td>0.422111</td>
#       <td>0.621579</td>
#       <td>0.586433</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.154081</td>
#       <td>1.357053</td>
#       <td>0.371859</td>
#       <td>0.622539</td>
#       <td>0.624665</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.837690</td>
#       <td>1.357355</td>
#       <td>0.351759</td>
#       <td>0.632117</td>
#       <td>0.643778</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.645114</td>
#       <td>1.343817</td>
#       <td>0.366834</td>
#       <td>0.621496</td>
#       <td>0.629417</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>
# /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/fastai/metrics.py:191: UserWarning: average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.
#   warn("average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.")

# %%
#learn.lr_find()
#learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(5, max_lr=slice(1e-4,1e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.964546</td>
#       <td>6.565542</td>
#       <td>0.663317</td>
#       <td>nan</td>
#       <td>0.333340</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.259103</td>
#       <td>9.427836</td>
#       <td>0.628141</td>
#       <td>nan</td>
#       <td>0.368009</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.079620</td>
#       <td>1.862195</td>
#       <td>0.371859</td>
#       <td>0.685121</td>
#       <td>0.621501</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.817604</td>
#       <td>1.134099</td>
#       <td>0.266332</td>
#       <td>0.755286</td>
#       <td>0.725507</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.625630</td>
#       <td>0.953616</td>
#       <td>0.231156</td>
#       <td>0.775267</td>
#       <td>0.763563</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
cm=interp.confusion_matrix()
df = pd.DataFrame(cm)
df.da.export_metrics()
# Out:
#                                   0         1         2         3         4  \
# accuracy                   0.969849  0.969849  0.939698  0.924623  0.959799
# f1                         0.833333  0.812500  0.750000  0.571429  0.809524
# false_discovery_rate       0.117647  0.187500  0.333333  0.333333  0.260870
# false_negative_rate        0.210526  0.187500  0.142857  0.500000  0.105263
# false_positive_rate        0.011111  0.016393  0.050562  0.027933  0.033333
# negative_predictive_value  0.978022  0.983607  0.982558  0.945652  0.988636
# positive_predictive_value  0.882353  0.812500  0.666667  0.666667  0.739130
# precision                  0.882353  0.812500  0.666667  0.666667  0.739130
# recall                     0.789474  0.812500  0.857143  0.500000  0.894737
# sensitivity                0.789474  0.812500  0.857143  0.500000  0.894737
# specificity                0.988889  0.983607  0.949438  0.972067  0.966667
# true_negative_rate         0.988889  0.983607  0.949438  0.972067  0.966667
# true_positive_rate         0.789474  0.812500  0.857143  0.500000  0.894737
#
#                                   5         6         7         8         9  \
# accuracy                   0.994975  0.984925  0.934673  0.949749  0.909548
# f1                         0.972973  0.938776  0.734694  0.666667  0.550000
# false_discovery_rate       0.000000  0.000000  0.307692  0.230769  0.476190
# false_negative_rate        0.052632  0.115385  0.217391  0.411765  0.421053
# false_positive_rate        0.000000  0.000000  0.045455  0.016484  0.055556
# negative_predictive_value  0.994475  0.982955  0.971098  0.962366  0.955056
# positive_predictive_value  1.000000  1.000000  0.692308  0.769231  0.523810
# precision                  1.000000  1.000000  0.692308  0.769231  0.523810
# recall                     0.947368  0.884615  0.782609  0.588235  0.578947
# sensitivity                0.947368  0.884615  0.782609  0.588235  0.578947
# specificity                1.000000  1.000000  0.954545  0.983516  0.944444
# true_negative_rate         1.000000  1.000000  0.954545  0.983516  0.944444
# true_positive_rate         0.947368  0.884615  0.782609  0.588235  0.578947
#
#                            micro-average
# accuracy                        0.953769
# f1                              0.768844
# false_discovery_rate            0.231156
# false_negative_rate             0.231156
# false_positive_rate             0.025684
# negative_predictive_value       0.974316
# positive_predictive_value       0.768844
# precision                       0.768844
# recall                          0.768844
# sensitivity                     0.768844
# specificity                     0.974316
# true_negative_rate              0.974316
# true_positive_rate              0.768844

# %% [markdown]
# ## With SqueezeNet

# %%
learn = create_cnn(data, models.squeezenet1_0, metrics=[error_rate,Precision(),Recall()])
# Out:
# /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/fastai/vision/learner.py:109: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.695641</td>
#       <td>1.526920</td>
#       <td>0.507538</td>
#       <td>0.475578</td>
#       <td>0.511223</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.961887</td>
#       <td>1.232001</td>
#       <td>0.371859</td>
#       <td>0.638665</td>
#       <td>0.640375</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.501787</td>
#       <td>1.187273</td>
#       <td>0.361809</td>
#       <td>0.640115</td>
#       <td>0.644220</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.164482</td>
#       <td>1.148648</td>
#       <td>0.326633</td>
#       <td>0.678136</td>
#       <td>0.681337</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.936701</td>
#       <td>1.189294</td>
#       <td>0.331658</td>
#       <td>0.673225</td>
#       <td>0.677337</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# /data/s2965003/.conda/envs/py38/lib/python3.8/site-packages/fastai/metrics.py:191: UserWarning: average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.
#   warn("average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.")

# %%
#learn.lr_find()
#learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(25, max_lr=slice(1e-4,1e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.611938</td>
#       <td>2.193702</td>
#       <td>0.391960</td>
#       <td>0.663098</td>
#       <td>0.609992</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.569327</td>
#       <td>1.515103</td>
#       <td>0.336683</td>
#       <td>0.684771</td>
#       <td>0.659753</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.540721</td>
#       <td>1.651123</td>
#       <td>0.386935</td>
#       <td>0.646256</td>
#       <td>0.615206</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.512473</td>
#       <td>2.336657</td>
#       <td>0.386935</td>
#       <td>0.668805</td>
#       <td>0.588496</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.493647</td>
#       <td>4.044066</td>
#       <td>0.532663</td>
#       <td>nan</td>
#       <td>0.478086</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.529475</td>
#       <td>3.157893</td>
#       <td>0.527638</td>
#       <td>nan</td>
#       <td>0.460689</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.554693</td>
#       <td>3.924956</td>
#       <td>0.522613</td>
#       <td>nan</td>
#       <td>0.490617</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.654566</td>
#       <td>5.458950</td>
#       <td>0.613065</td>
#       <td>nan</td>
#       <td>0.393069</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.777926</td>
#       <td>13.536124</td>
#       <td>0.678392</td>
#       <td>nan</td>
#       <td>0.306834</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.963249</td>
#       <td>14.692245</td>
#       <td>0.698492</td>
#       <td>nan</td>
#       <td>0.278169</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.071556</td>
#       <td>12.485023</td>
#       <td>0.768844</td>
#       <td>nan</td>
#       <td>0.251281</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.088773</td>
#       <td>2.254677</td>
#       <td>0.507538</td>
#       <td>0.625796</td>
#       <td>0.476665</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.056822</td>
#       <td>4.244607</td>
#       <td>0.587940</td>
#       <td>nan</td>
#       <td>0.401770</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.993752</td>
#       <td>4.312309</td>
#       <td>0.653266</td>
#       <td>nan</td>
#       <td>0.329086</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.924518</td>
#       <td>4.474142</td>
#       <td>0.557789</td>
#       <td>nan</td>
#       <td>0.422182</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.856775</td>
#       <td>6.541369</td>
#       <td>0.748744</td>
#       <td>nan</td>
#       <td>0.231087</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.806387</td>
#       <td>5.240727</td>
#       <td>0.527638</td>
#       <td>nan</td>
#       <td>0.470963</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.771948</td>
#       <td>2.176483</td>
#       <td>0.381910</td>
#       <td>0.703977</td>
#       <td>0.606510</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.724783</td>
#       <td>2.323061</td>
#       <td>0.467337</td>
#       <td>0.691621</td>
#       <td>0.501646</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.666580</td>
#       <td>4.947974</td>
#       <td>0.613065</td>
#       <td>nan</td>
#       <td>0.355527</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.616748</td>
#       <td>3.767740</td>
#       <td>0.547739</td>
#       <td>nan</td>
#       <td>0.405342</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.572352</td>
#       <td>7.348333</td>
#       <td>0.683417</td>
#       <td>nan</td>
#       <td>0.367769</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.508887</td>
#       <td>2.665471</td>
#       <td>0.427136</td>
#       <td>nan</td>
#       <td>0.550978</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.466618</td>
#       <td>4.370922</td>
#       <td>0.497487</td>
#       <td>nan</td>
#       <td>0.490913</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.444129</td>
#       <td>4.217329</td>
#       <td>0.532663</td>
#       <td>nan</td>
#       <td>0.479209</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.427048</td>
#       <td>3.428599</td>
#       <td>0.542714</td>
#       <td>0.723116</td>
#       <td>0.478168</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.391279</td>
#       <td>2.256544</td>
#       <td>0.331658</td>
#       <td>0.634072</td>
#       <td>0.655572</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.357572</td>
#       <td>2.196869</td>
#       <td>0.412060</td>
#       <td>0.699575</td>
#       <td>0.560567</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.319329</td>
#       <td>2.485531</td>
#       <td>0.412060</td>
#       <td>0.642664</td>
#       <td>0.548677</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.294253</td>
#       <td>5.179272</td>
#       <td>0.567839</td>
#       <td>nan</td>
#       <td>0.400042</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.264744</td>
#       <td>4.111124</td>
#       <td>0.477387</td>
#       <td>nan</td>
#       <td>0.539453</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.229932</td>
#       <td>2.797318</td>
#       <td>0.407035</td>
#       <td>0.727224</td>
#       <td>0.619312</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.197421</td>
#       <td>1.924771</td>
#       <td>0.291457</td>
#       <td>0.713722</td>
#       <td>0.700349</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.163976</td>
#       <td>1.556075</td>
#       <td>0.246231</td>
#       <td>0.794972</td>
#       <td>0.738068</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.134780</td>
#       <td>1.521463</td>
#       <td>0.291457</td>
#       <td>0.740487</td>
#       <td>0.706860</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.113896</td>
#       <td>1.864813</td>
#       <td>0.306533</td>
#       <td>0.735355</td>
#       <td>0.702571</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.094035</td>
#       <td>1.732889</td>
#       <td>0.276382</td>
#       <td>0.759669</td>
#       <td>0.729581</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.077018</td>
#       <td>1.504940</td>
#       <td>0.266332</td>
#       <td>0.756732</td>
#       <td>0.731779</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.064022</td>
#       <td>1.516685</td>
#       <td>0.261307</td>
#       <td>0.759361</td>
#       <td>0.740935</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.056213</td>
#       <td>1.478837</td>
#       <td>0.241206</td>
#       <td>0.779047</td>
#       <td>0.758959</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.048601</td>
#       <td>1.460463</td>
#       <td>0.241206</td>
#       <td>0.766355</td>
#       <td>0.759580</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.041033</td>
#       <td>1.466560</td>
#       <td>0.251256</td>
#       <td>0.749006</td>
#       <td>0.751225</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.034475</td>
#       <td>1.531091</td>
#       <td>0.256281</td>
#       <td>0.750470</td>
#       <td>0.748343</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.029721</td>
#       <td>1.552870</td>
#       <td>0.261307</td>
#       <td>0.746042</td>
#       <td>0.742909</td>
#       <td>00:05</td>
#     </

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
cm=interp.confusion_matrix()
df = pd.DataFrame(cm)
df.da.export_metrics()
# Out:
#                                   0         1         2         3         4  \
# accuracy                   0.959799  0.979899  0.929648  0.909548  0.969849
# f1                         0.800000  0.928571  0.681818  0.590909  0.785714
# false_discovery_rate       0.238095  0.103448  0.210526  0.277778  0.214286
# false_negative_rate        0.157895  0.037037  0.400000  0.500000  0.214286
# false_positive_rate        0.027778  0.017442  0.022989  0.028902  0.016216
# negative_predictive_value  0.983146  0.994118  0.944444  0.928177  0.983784
# positive_predictive_value  0.761905  0.896552  0.789474  0.722222  0.785714
# precision                  0.761905  0.896552  0.789474  0.722222  0.785714
# recall                     0.842105  0.962963  0.600000  0.500000  0.785714
# sensitivity                0.842105  0.962963  0.600000  0.500000  0.785714
# specificity                0.972222  0.982558  0.977011  0.971098  0.983784
# true_negative_rate         0.972222  0.982558  0.977011  0.971098  0.983784
# true_positive_rate         0.842105  0.962963  0.600000  0.500000  0.785714
#
#                                   5         6         7         8         9  \
# accuracy                   0.974874  0.974874  0.944724  0.939698  0.894472
# f1                         0.848485  0.871795  0.702703  0.666667  0.487805
# false_discovery_rate       0.066667  0.055556  0.409091  0.368421  0.583333
# false_negative_rate        0.222222  0.190476  0.133333  0.294118  0.411765
# false_positive_rate        0.005525  0.005618  0.048913  0.038462  0.076923
# negative_predictive_value  0.978261  0.977901  0.988701  0.972222  0.960000
# positive_predictive_value  0.933333  0.944444  0.590909  0.631579  0.416667
# precision                  0.933333  0.944444  0.590909  0.631579  0.416667
# recall                     0.777778  0.809524  0.866667  0.705882  0.588235
# sensitivity                0.777778  0.809524  0.866667  0.705882  0.588235
# specificity                0.994475  0.994382  0.951087  0.961538  0.923077
# true_negative_rate         0.994475  0.994382  0.951087  0.961538  0.923077
# true_positive_rate         0.777778  0.809524  0.866667  0.705882  0.588235
#
#                            micro-average
# accuracy                        0.947739
# f1                              0.738693
# false_discovery_rate            0.261307
# false_negative_rate             0.261307
# false_positive_rate             0.029034
# negative_predictive_value       0.970966
# positive_predictive_value       0.738693
# precision                       0.738693
# recall                          0.738693
# sensitivity                     0.738693
# specificity                     0.970966
# true_negative_rate              0.970966
# true_positive_rate              0.738693
